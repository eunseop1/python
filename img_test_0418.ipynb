# %%
pip install ultralytics
# Out:
# ...
#      ---------------------------------------- 0.0/40.5 kB ? eta -:--:--
#      ---------------------------------------- 40.5/40.5 kB 2.0 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 0.0/60.6 kB ? eta -:--:--
#      ---------------------------------------- 60.6/60.6 kB 3.4 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 0.0/57.6 kB ? eta -:--:--
#      ----------------------------------- ---- 51.2/57.6 kB 1.3 MB/s eta 0:00:01
#      ---------------------------------------- 57.6/57.6 kB 1.0 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/750.8 kB ? eta -:--:--
#    - -------------------------------------- 30.7/750.8 kB 1.4 MB/s eta 0:00:01
#    --- ----------------------------------- 71.7/750.8 kB 991.0 kB/s eta 0:00:01
#    ----- -------------------------------- 112.6/750.8 kB 819.2 kB/s eta 0:00:01
#    ------- ------------------------------ 153.6/750.8 kB 833.5 kB/s eta 0:00:01
# ...

# %%
from ultralytics import YOLO

# https://docs.ultralytics.com/models/yolov8/#usage-examples
# 욜로에 대한 부분은 이 사이트를 통해서 찾아 낼수 있다
# 욜로는 이미지를 리스트로도 넣을 수 있다

# Load a model
model = YOLO('yolov8n.pt')  # pretrained YOLOv8n model
# 욜로의 모델은 다양하다
# yolob8n, yolov8s, yolov8m, yolov8l, yolov8x
# 오른쪽으로 갈수록 성능은 향상되지만, 이미지에 비해 너무 높은 성능을 사용하면 인식률이 떨어진다

# Run batched inference on a list of images
# results = model([r'D:\Windows_user\Desktop\python\test.jpg'])# return a list of Results objects
results = model([r'D:\Windows_user\Downloads\AI_human.jpg'])

# print(results)

# Process results list
for result in results:
    boxes = result.boxes  # Boxes object for bounding box outputs
    masks = result.masks  # Masks object for segmentation masks outputs
    keypoints = result.keypoints  # Keypoints object for pose outputs
    probs = result.probs  # Probs object for classification outputs
    result.show()  # display to screen
    result.save(filename='result.jpg')  # save to disk
# Out:
# 0: 384x640 36 persons, 47.3ms
# Speed: 1.0ms preprocess, 47.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
